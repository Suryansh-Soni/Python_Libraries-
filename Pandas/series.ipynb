# %% [markdown]
# # Series in pandas
# ### 1D array That can store anything

# %%
import numpy as np
import pandas as pd

# %%
label=['a','b','c']
list=[10,20,30]
arr=np.array([1,2,3,4])
dict={1:20,2:30,3:40}
pd.Series(list,index=label)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
pd.Series(dict)
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64
